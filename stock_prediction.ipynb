# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (2.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.23.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (0.13.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (2.14.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('GOOG.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 34s 367ms/step - loss: 0.0064 - mean_absolute_error: 0.0590 - val_loss: 0.0128 - val_mean_absolute_error: 0.0902
# Epoch 2/100
# 28/28 [==============================] - 4s 154ms/step - loss: 7.9654e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0050 - val_mean_absolute_error: 0.0557
# Epoch 3/100
# 28/28 [==============================] - 5s 163ms/step - loss: 4.6144e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0030 - val_mean_absolute_error: 0.0419
# Epoch 4/100
# 28/28 [==============================] - 5s 164ms/step - loss: 4.4199e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0052 - val_mean_absolute_error: 0.0572
# Epoch 5/100
# 28/28 [==============================] - 5s 177ms/step - loss: 4.4437e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 6/100
# 28/28 [==============================] - 5s 168ms/step - loss: 4.5859e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0028 - val_mean_absolute_error: 0.0394
# Epoch 7/100
# 28/28 [==============================] - 5s 169ms/step - loss: 4.6305e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0057 - val_mean_absolute_error: 0.0601
# Epoch 8/100
# 28/28 [==============================] - 5s 171ms/step - loss: 4.1173e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0036 - val_mean_absolute_error: 0.0457
# Epoch 9/100
# 28/28 [==============================] - 5s 181ms/step - loss: 4.3405e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0070 - val_mean_absolute_error: 0.0683
# Epoch 10/100
# 28/28 [==============================] - 5s 163ms/step - loss: 4.1102e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0045 - val_mean_absolute_error: 0.0522
# Epoch 11/100
# 28/28 [==============================] - 4s 160ms/step - loss: 3.5933e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0051 - val_mean_absolute_error: 0.0561
# Epoch 12/100
# 28/28 [==============================] - 4s 157ms/step - loss: 4.0618e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0049 - val_mean_absolute_error: 0.0544
# Epoch 13/100
# 28/28 [==============================] - 5s 168ms/step - loss: 3.6563e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0044 - val_mean_absolute_error: 0.0507
# Epoch 14/100
# 28/28 [==============================] - 5s 174ms/step - loss: 3.6352e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0075 - val_mean_absolute_error: 0.0702
# Epoch 15/100
# 28/28 [==============================] - 5s 174ms/step - loss: 3.3032e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0058 - val_mean_absolute_error: 0.0600
# Epoch 16/100
# 28/28 [==============================] - 5s 172ms/step - loss: 3.3147e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0052 - val_mean_absolute_error: 0.0570
# Epoch 17/100
# 28/28 [==============================] - 5s 169ms/step - loss: 3.4057e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0070 - val_mean_absolute_error: 0.0663
# Epoch 18/100
# 28/28 [==============================] - 5s 173ms/step - loss: 3.5418e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0044 - val_mean_absolute_error: 0.0511
# Epoch 19/100
# 28/28 [==============================] - 4s 159ms/step - loss: 3.2290e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0075 - val_mean_absolute_error: 0.0702
# Epoch 20/100
# 28/28 [==============================] - 5s 171ms/step - loss: 3.2927e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0054 - val_mean_absolute_error: 0.0575
# Epoch 21/100
# 28/28 [==============================] - 5s 170ms/step - loss: 3.1088e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0066 - val_mean_absolute_error: 0.0648
# Epoch 22/100
# 28/28 [==============================] - 5s 180ms/step - loss: 2.9209e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0030 - val_mean_absolute_error: 0.0410
# Epoch 23/100
# 28/28 [==============================] - 5s 172ms/step - loss: 3.3621e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0052 - val_mean_absolute_error: 0.0564
# Epoch 24/100
# 28/28 [==============================] - 4s 162ms/step - loss: 2.9556e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0076 - val_mean_absolute_error: 0.0705
# Epoch 25/100
# 28/28 [==============================] - 5s 163ms/step - loss: 2.9773e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0035 - val_mean_absolute_error: 0.0446
# Epoch 26/100
# 28/28 [==============================] - 5s 176ms/step - loss: 2.8950e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 27/100
# 28/28 [==============================] - 5s 185ms/step - loss: 2.6492e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0057 - val_mean_absolute_error: 0.0594
# Epoch 28/100
# 28/28 [==============================] - 5s 169ms/step - loss: 2.6451e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0092 - val_mean_absolute_error: 0.0772
# Epoch 29/100
# 28/28 [==============================] - 5s 166ms/step - loss: 2.7632e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0046 - val_mean_absolute_error: 0.0517
# Epoch 30/100
# 28/28 [==============================] - 5s 165ms/step - loss: 2.8991e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0037 - val_mean_absolute_error: 0.0466
# Epoch 31/100
# 28/28 [==============================] - 5s 182ms/step - loss: 3.1087e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0035 - val_mean_absolute_error: 0.0458
# Epoch 32/100
# 28/28 [==============================] - 5s 164ms/step - loss: 2.5705e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0057 - val_mean_absolute_error: 0.0612
# Epoch 33/100
# 28/28 [==============================] - 5s 185ms/step - loss: 2.6519e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0068 - val_mean_absolute_error: 0.0673
# Epoch 34/100
# 28/28 [==============================] - 5s 184ms/step - loss: 2.4702e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0058 - val_mean_absolute_error: 0.0606
# Epoch 35/100
# 28/28 [==============================] - 5s 171ms/step - loss: 2.5616e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0039 - val_mean_absolute_error: 0.0477
# Epoch 36/100
# 28/28 [==============================] - 5s 175ms/step - loss: 2.4554e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0043 - val_mean_absolute_error: 0.0494
# Epoch 37/100
# 28/28 [==============================] - 5s 182ms/step - loss: 2.6977e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0121 - val_mean_absolute_error: 0.0920
# Epoch 38/100
# 28/28 [==============================] - 5s 167ms/step - loss: 3.0041e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0040 - val_mean_absolute_error: 0.0485
# Epoch 39/100
# 28/28 [==============================] - 5s 168ms/step - loss: 2.6888e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470
# Epoch 40/100
# 28/28 [==============================] - 5s 173ms/step - loss: 2.5236e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0040 - val_mean_absolute_error: 0.0496
# Epoch 41/100
# 28/28 [==============================] - 4s 153ms/step - loss: 2.2086e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0046 - val_mean_absolute_error: 0.0545
# Epoch 42/100
# 28/28 [==============================] - 5s 166ms/step - loss: 2.2151e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 43/100
# 28/28 [==============================] - 5s 172ms/step - loss: 2.1264e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0042 - val_mean_absolute_error: 0.0508
# Epoch 44/100
# 28/28 [==============================] - 5s 168ms/step - loss: 2.1468e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0034 - val_mean_absolute_error: 0.0442
# Epoch 45/100
# 28/28 [==============================] - 5s 173ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 46/100
# 28/28 [==============================] - 5s 183ms/step - loss: 2.1098e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0045 - val_mean_absolute_error: 0.0516
# Epoch 47/100
# 28/28 [==============================] - 5s 185ms/step - loss: 2.0653e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0061 - val_mean_absolute_error: 0.0616
# Epoch 48/100
# 28/28 [==============================] - 5s 168ms/step - loss: 2.0659e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0044 - val_mean_absolute_error: 0.0511
# Epoch 49/100
# 28/28 [==============================] - 5s 176ms/step - loss: 2.3158e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0029 - val_mean_absolute_error: 0.0403
# Epoch 50/100
# 28/28 [==============================] - 5s 169ms/step - loss: 2.1385e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0038 - val_mean_absolute_error: 0.0481
# Epoch 51/100
# 28/28 [==============================] - 5s 166ms/step - loss: 2.0134e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0039 - val_mean_absolute_error: 0.0489
# Epoch 52/100
# 28/28 [==============================] - 5s 168ms/step - loss: 2.0412e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0056 - val_mean_absolute_error: 0.0601
# Epoch 53/100
# 28/28 [==============================] - 5s 178ms/step - loss: 1.8907e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 54/100
# 28/28 [==============================] - 5s 172ms/step - loss: 1.9044e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0022 - val_mean_absolute_error: 0.0347
# Epoch 55/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.8996e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0033 - val_mean_absolute_error: 0.0428
# Epoch 56/100
# 28/28 [==============================] - 5s 178ms/step - loss: 1.8899e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0047 - val_mean_absolute_error: 0.0551
# Epoch 57/100
# 28/28 [==============================] - 5s 173ms/step - loss: 1.9367e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0044 - val_mean_absolute_error: 0.0515
# Epoch 58/100
# 28/28 [==============================] - 5s 187ms/step - loss: 2.0878e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 59/100
# 28/28 [==============================] - 5s 167ms/step - loss: 2.1216e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0031 - val_mean_absolute_error: 0.0438
# Epoch 60/100
# 28/28 [==============================] - 5s 177ms/step - loss: 1.8561e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0070 - val_mean_absolute_error: 0.0678
# Epoch 61/100
# 28/28 [==============================] - 5s 172ms/step - loss: 1.8879e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0056 - val_mean_absolute_error: 0.0591
# Epoch 62/100
# 28/28 [==============================] - 5s 170ms/step - loss: 1.8278e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0056 - val_mean_absolute_error: 0.0592
# Epoch 63/100
# 28/28 [==============================] - 5s 167ms/step - loss: 1.7055e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0056 - val_mean_absolute_error: 0.0592
# Epoch 64/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.9242e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 65/100
# 28/28 [==============================] - 5s 175ms/step - loss: 1.6975e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0039 - val_mean_absolute_error: 0.0496
# Epoch 66/100
# 28/28 [==============================] - 5s 182ms/step - loss: 1.6041e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 67/100
# 28/28 [==============================] - 5s 170ms/step - loss: 1.5389e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0033 - val_mean_absolute_error: 0.0451
# Epoch 68/100
# 28/28 [==============================] - 5s 176ms/step - loss: 1.5995e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 69/100
# 28/28 [==============================] - 5s 175ms/step - loss: 1.5672e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0088 - val_mean_absolute_error: 0.0785
# Epoch 70/100
# 28/28 [==============================] - 5s 165ms/step - loss: 1.7654e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0044 - val_mean_absolute_error: 0.0528
# Epoch 71/100
# 28/28 [==============================] - 5s 176ms/step - loss: 1.4403e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0026 - val_mean_absolute_error: 0.0394
# Epoch 72/100
# 28/28 [==============================] - 5s 189ms/step - loss: 1.4665e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 73/100
# 28/28 [==============================] - 5s 178ms/step - loss: 1.7397e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0037 - val_mean_absolute_error: 0.0499
# Epoch 74/100
# 28/28 [==============================] - 5s 185ms/step - loss: 1.4701e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0024 - val_mean_absolute_error: 0.0378
# Epoch 75/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.4677e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0040 - val_mean_absolute_error: 0.0489
# Epoch 76/100
# 28/28 [==============================] - 5s 175ms/step - loss: 1.5188e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 77/100
# 28/28 [==============================] - 5s 169ms/step - loss: 1.5576e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271
# Epoch 78/100
# 28/28 [==============================] - 5s 167ms/step - loss: 1.4513e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0029 - val_mean_absolute_error: 0.0419
# Epoch 79/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.3929e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0023 - val_mean_absolute_error: 0.0368
# Epoch 80/100
# 28/28 [==============================] - 5s 162ms/step - loss: 1.2795e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451
# Epoch 81/100
# 28/28 [==============================] - 5s 170ms/step - loss: 1.2829e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0042 - val_mean_absolute_error: 0.0527
# Epoch 82/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.5487e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0039 - val_mean_absolute_error: 0.0496
# Epoch 83/100
# 28/28 [==============================] - 5s 183ms/step - loss: 1.3770e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0038 - val_mean_absolute_error: 0.0488
# Epoch 84/100
# 28/28 [==============================] - 6s 205ms/step - loss: 1.3664e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0026 - val_mean_absolute_error: 0.0394
# Epoch 85/100
# 28/28 [==============================] - 6s 199ms/step - loss: 1.2095e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0026 - val_mean_absolute_error: 0.0395
# Epoch 86/100
# 28/28 [==============================] - 5s 180ms/step - loss: 1.2479e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 87/100
# 28/28 [==============================] - 5s 196ms/step - loss: 1.1821e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0027 - val_mean_absolute_error: 0.0411
# Epoch 88/100
# 28/28 [==============================] - 5s 191ms/step - loss: 1.1693e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 89/100
# 28/28 [==============================] - 5s 184ms/step - loss: 1.3733e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0030 - val_mean_absolute_error: 0.0438
# Epoch 90/100
# 28/28 [==============================] - 5s 182ms/step - loss: 1.2327e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 91/100
# 28/28 [==============================] - 5s 164ms/step - loss: 1.1967e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 92/100
# 28/28 [==============================] - 5s 174ms/step - loss: 1.2212e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 93/100
# 28/28 [==============================] - 5s 179ms/step - loss: 1.2627e-04 - mean_absolute_error: 0.0081 - val_loss: 8.8145e-04 - val_mean_absolute_error: 0.0219
# Epoch 94/100
# 28/28 [==============================] - 5s 190ms/step - loss: 1.1581e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0036 - val_mean_absolute_error: 0.0480
# Epoch 95/100
# 28/28 [==============================] - 5s 189ms/step - loss: 1.2288e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 96/100
# 28/28 [==============================] - 5s 187ms/step - loss: 1.0899e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 97/100
# 28/28 [==============================] - 5s 178ms/step - loss: 1.1322e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
# Epoch 98/100
# 28/28 [==============================] - 5s 180ms/step - loss: 1.0183e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 99/100
# 28/28 [==============================] - 5s 185ms/step - loss: 1.1523e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0024 - val_mean_absolute_error: 0.0387
# Epoch 100/100
# 28/28 [==============================] - 5s 177ms/step - loss: 1.1772e-04 - mean_absolute_error: 0.0076 - val_loss: 9.6450e-04 - val_mean_absolute_error: 0.0232

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 5s 42ms/step
# array([[0.4056169 , 0.4043026 ],
#        [0.40601957, 0.40451288],
#        [0.40337095, 0.40159523],
#        [0.4071515 , 0.4050718 ],
#        [0.41112676, 0.4090767 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1422.9812, 1417.5702],
#        [1423.7278, 1417.96  ],
#        [1418.8174, 1412.5526],
#        [1425.8263, 1418.9958],
#        [1433.196 , 1426.4182]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1422.981201      1417.570190
# 2020-05-28  1396.86  1416.73     1423.727783      1417.959961
# 2020-05-29  1416.94  1428.92     1418.817383      1412.552612
# 2020-06-01  1418.39  1431.82     1425.826294      1418.995850
# 2020-06-02  1430.55  1439.22     1433.196045      1426.418213

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
import pandas as pd
import numpy as np

# Create a date range for the index
start_date = '2021-06-09'
end_date = '2021-06-16'
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# Create data for the DataFrame
data = {
    'open': [2499.50, 2494.01, 2524.92, np.nan, np.nan, np.nan, np.nan, np.nan],
    'close': [2491.40, 2521.60, 2513.93, np.nan, np.nan, np.nan, np.nan, np.nan],
    'open_predicted': [2419.937012, 2429.809814, 2435.215576, np.nan, np.nan, np.nan, np.nan, np.nan],
    'close_predicted': [2351.718994, 2357.459229, 2360.057861, np.nan, np.nan, np.nan, np.nan, np.nan]
}

# Create the DataFrame
df = pd.DataFrame(data, index=date_range)

# Print the DataFrame
print(df)
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2419.937012      2351.718994
# 2021-06-10  2494.01  2521.60     2429.809814      2357.459229
# 2021-06-11  2524.92  2513.93     2435.215576      2360.057861
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
